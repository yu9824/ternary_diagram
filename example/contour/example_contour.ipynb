# %%
from ternary_diagram import ternary_diagram
import pandas as pd

# %%
df = pd.read_csv('example_contour.csv')

# %%
fig = ternary_diagram(df.columns[0:-1], df.iloc[:, 0:-1], df.iloc[:, -1], minimum = 0, maiximum = 1, bar_label = 'example_contour', norm = True, mode = 'contour')
