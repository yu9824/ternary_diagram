# %% [markdown]
# ### デバッグ用 (ternary_diagramをインストールしている場合は不要)

# %%
import sys
import os
sys.path.append(os.path.join(os.getcwd(), '../../ternary_diagram'))

# %% [markdown]
# ### モジュールのインストール

# %%
from ternary_diagram import ternary_diagram
import pandas as pd

# %%
df = pd.read_csv('example_contour.csv')

# %%
td = ternary_diagram(df.columns[0:-1])  # 三角形のラベルを半時計周りに指定
td.contour(df.iloc[:, 0:-1], z = df.iloc[:, -1], minimum = 0, maiximum = 1, bar_label = 'example_contour', norm = True)

# %%
td.fig.savefig('example_contour.png', dpi = 300)
