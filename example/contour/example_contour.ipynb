# %%
import ternary_diagram
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-986d600174ac> in <module>
# ----> 1 import ternary_diagram
#
# ModuleNotFoundError: No module named 'ternary_diagram'
