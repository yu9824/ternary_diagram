# %%
from ternary_diagram import ternary_diagram
import pandas as pd

# %%
df = pd.read_csv('example_scatter.csv')

# %%
fig = ternary_diagram(df.columns[0:-1], df.iloc[:, 0:-1], df.iloc[:, -1], minimum = 0, maximum = 1, norm = True, mode = 'scatter')
