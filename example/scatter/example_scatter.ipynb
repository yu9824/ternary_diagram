# %% [markdown]
# ### デバッグ用 (ternary_diagramをインストールしている場合は不要)

# %%
import sys
import os
sys.path.append(os.path.join(os.getcwd(), '../../ternary_diagram'))

# %% [markdown]
# ### モジュールインポート

# %%
from ternary_diagram import ternary_diagram
import pandas as pd

# %%
df = pd.read_csv('example_scatter.csv')

# %%
td = ternary_diagram(df.columns[0:-1])
td.scatter(df.iloc[:, 0:-1], z = df.iloc[:, -1], minimum = 0, maximum = 1)

# %%
td.fig.savefig('example_scatter.png', dpi = 300)
