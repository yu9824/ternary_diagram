# %% [markdown]
# ### デバッグ用

# %%
import os
import sys
sys.path.insert(0, os.path.join(os.getcwd(), '..', '..'))

# %%
from ternary_diagram import TernaryDiagram
from element_recognition import get_ratio

# %%
materials = ['Li4SiO4', 'Li4GeO4', 'Li4SnO4']
products = ['Li4Si0.1Ge0.4Sn0.5O4']

# %%
ratio = get_ratio(materials = materials, products = products)
ratio
# Out:
#                       Li4SiO4  Li4GeO4  Li4SnO4
# Li4Si0.1Ge0.4Sn0.5O4      0.1      0.4      0.5

# %%
td = TernaryDiagram(materials = materials)

# %%
td.scatter(ratio, annotations = list(map(td._get_label, ratio.index)))
td.fig

# %%
td.fig.savefig('example_scatter_with_annotations.png', dpi = 150)
