# %% [markdown]
# ### デバッグ用 (ternary_diagramをインストールしている場合は不要)

# %%
import sys
import os
sys.path.append(os.path.join(os.getcwd(), '../../ternary_diagram'))

# %% [markdown]
# ### モジュールインポート

# %%
from ternary_diagram import ternary_diagram
import pandas as pd

# %%
df = pd.read_csv('example_mono_scatter.csv')

# %% [markdown]
# ### プロットのみ

# %%
td = ternary_diagram(df.columns)
td.scatter(df, color = 'blue', facecolor = "None", lw = 2)

# %% [markdown]
# ### 連結線を引く場合

# %%
td = ternary_diagram(df.columns)
td.scatter(df)
td.plot([1,0,1],[0,2,3])

# %%
td.fig.savefig('example_mono_scatter.png', dpi = 300)
